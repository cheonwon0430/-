# %% [markdown]
# <a href="https://colab.research.google.com/github/cheonwon0430/-/blob/master/%EB%94%B0%EB%A6%89%EC%9D%B4_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 따릉이 데이터를 활용한 데이터 분석

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# - 각 날짜의 1시간 전의 기상상황을 가지고 1시간 후의 따릉이 대여수를 예측해보세요.

# %% [markdown]
# ## 1. 라이브러리 및 데이터
# ## Library & Data

# %%
import pandas as pd #판다스 패키지 불러오기
from sklearn.tree import DecisionTreeRegressor  #랜덤 포레스트 설명용
from sklearn.ensemble import RandomForestRegressor  #랜덤 포레스트 불러오기

# %%
# 데이터 불러오기
submission = pd.read_csv('/content/drive/MyDrive/따릉이/submission.csv')# 답안지 파일
test = pd.read_csv('/content/drive/MyDrive/따릉이/test.csv')# 모델 시험지 파일
train = pd.read_csv('/content/drive/MyDrive/따릉이/train.csv')# 모델 학습 파일

# %% [markdown]
# ## 2. 탐색적 자료분석
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### pd.DataFrame.head()
#  - 데이터 프레임의 위에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.head()
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   3    20                  16.3                     1.0                 1.5
# 1   6    13                  20.1                     0.0                 1.4
# 2   7     6                  13.9                     0.0                 0.7
# 3   8    23                   8.1                     0.0                 2.7
# 4   9    18                  29.5                     0.0                 4.8
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               89.0                576.0           0.027           76.0
# 1               48.0                916.0           0.042           73.0
# 2               79.0               1382.0           0.033           32.0
# 3               54.0                946.0           0.040           75.0
# 4                7.0               2000.0           0.057           27.0
#
#    hour_bef_pm2.5  count
# 0            33.0   49.0
# ...

# %% [markdown]
# + id : 날짜와 시간별 id
# + hour_bef_temperature : 1시간 전 기온
# + hour_bef_precipitation : 1시간 전 비 정보, 비가 오지 않았으면 0, 비가 오면 1
# + hour_bef_windspeed : 1시간 전 풍속(평균)
# + hour_bef_humidity : 1시간 전 습도
# + hour_bef_visibility : 1시간 전 시정(視程), 시계(視界)(특정 기상 상태에 따른 가시성을 의미)
# + hour_bef_ozone : 1시간 전 오존
# + hour_bef_pm10 : 1시간 전 미세먼지(머리카락 굵기의 1/5에서 1/7 크기의 미세먼지)
# + hour_bef_pm2.5 : 1시간 전 미세먼지(머리카락 굵기의 1/20에서 1/30 크기의 미세먼지)
# + count : 시간에 따른 따릉이 대여 수

# %%
test.head() #count 없음
# Out:
#    id  hour  hour_bef_temperature  hour_bef_precipitation  hour_bef_windspeed  \
# 0   0     7                  20.7                     0.0                 1.3
# 1   1    17                  30.0                     0.0                 5.4
# 2   2    13                  19.0                     1.0                 2.1
# 3   4     6                  22.5                     0.0                 2.5
# 4   5    22                  14.6                     1.0                 3.4
#
#    hour_bef_humidity  hour_bef_visibility  hour_bef_ozone  hour_bef_pm10  \
# 0               62.0                954.0           0.041           44.0
# 1               33.0               1590.0           0.061           49.0
# 2               95.0                193.0           0.020           36.0
# 3               60.0               1185.0           0.027           52.0
# 4               93.0                218.0           0.041           18.0
#
#    hour_bef_pm2.5
# 0            27.0
# 1            36.0
# ...

# %%
submission.head()
# Out:
#    id  count
# 0   0    NaN
# 1   1    NaN
# 2   2    NaN
# 3   4    NaN
# 4   5    NaN

# %% [markdown]
# ### pd.DataFrame.tail()
#  - 데이터 프레임의 아래에서 부터 n개 행을 보여주는 함수
#  - n의 기본 값(default 값)은 5

# %%
train.tail()
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 1454  2174     4                  16.8                     0.0
# 1455  2175     3                  10.8                     0.0
# 1456  2176     5                  18.3                     0.0
# 1457  2178    21                  20.7                     0.0
# 1458  2179    17                  21.1                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 1454                 1.6               53.0               2000.0
# 1455                 3.8               45.0               2000.0
# 1456                 1.9               54.0               2000.0
# 1457                 3.7               37.0               1395.0
# 1458                 3.1               47.0               1973.0
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 1454           0.031           37.0            27.0   21.0
# 1455           0.039           34.0            19.0   20.0
# ...

# %% [markdown]
# ### pd.DataFrame.shape
#  - 데이터 프레임의 행의 개수와 열의 개수가 저장되어 있는 속성(attribute)

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (1459, 11)
# (715, 10)
# (715, 2)

# %% [markdown]
# ### pd.DataFrame.info()
# - 데이터셋의 column별 정보를 알려주는 함수
# - 비어 있지 않은 값은 (non-null)은 몇개인지?
# - column의 type은 무엇인지?
#  - type의 종류 : int(정수), float(실수), object(문자열), 등등 (date, ...)

# %%
train.info() # 전체적으로 많이 비어있음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      1459 non-null   int64
#  1   hour                    1459 non-null   int64
#  2   hour_bef_temperature    1457 non-null   float64
#  3   hour_bef_precipitation  1457 non-null   float64
#  4   hour_bef_windspeed      1450 non-null   float64
#  5   hour_bef_humidity       1457 non-null   float64
#  6   hour_bef_visibility     1457 non-null   float64
#  7   hour_bef_ozone          1383 non-null   float64
#  8   hour_bef_pm10           1369 non-null   float64
#  9   hour_bef_pm2.5          1342 non-null   float64
#  10  count                   1459 non-null   float64
# dtypes: float64(9), int64(2)
# memory usage: 125.5 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      715 non-null    int64
#  1   hour                    715 non-null    int64
#  2   hour_bef_temperature    714 non-null    float64
#  3   hour_bef_precipitation  714 non-null    float64
#  4   hour_bef_windspeed      714 non-null    float64
#  5   hour_bef_humidity       714 non-null    float64
#  6   hour_bef_visibility     714 non-null    float64
#  7   hour_bef_ozone          680 non-null    float64
#  8   hour_bef_pm10           678 non-null    float64
#  9   hour_bef_pm2.5          679 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 56.0 KB

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      715 non-null    int64
#  1   count   0 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 11.3 KB

# %% [markdown]
# ### pd.DataFrame.describe()
# - 숫자형 (int, float) column들의 기술 통계량을 보여주는 함수
#
# - 기술통계량이란?
#  - 해당 column을 대표할 수 있는 통계값들을 의미
#
#
# - 기술통계량 종류
#  - count: 해당 column에서 비어 있지 않은 값의 개수
#  - mean: 평균
#  - std: 표준편차
#  - min: 최솟값 (이상치 포함)
#  - 25% (Q1): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 1/4번째 지점에 있는 값
#  - 50% (Q2): 중앙값 (전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 2/4번째 지점에 있는 값)
#  - 75% (Q3): 전체 데이터를 순서대로 정렬했을 때, 아래에서 부터 3/4번째 지점에 있는 값
#  - max: 최댓값 (이상치 포함)
#
#
#
# - 이상치: 울타리 밖에 있는 부분을 이상치라고 정의함
#    - 아래쪽 울타리: $Q_1$ - $1.5 * IQR$
#    - 위쪽 울타리: $Q_3$ + $1.5 * IQR$
#    - $IQR$ = $Q_3 - Q_1$
#
#
# <img src="https://miro.medium.com/max/10125/1*NRlqiZGQdsIyAu0KzP7LaQ.png" width="700" height="500">

# %%
train.describe()
# Out:
#                 id         hour  hour_bef_temperature  hour_bef_precipitation  \
# count  1459.000000  1459.000000           1457.000000             1457.000000
# mean   1105.914325    11.493489             16.717433                0.031572
# std     631.338681     6.922790              5.239150                0.174917
# min       3.000000     0.000000              3.100000                0.000000
# 25%     555.500000     5.500000             12.800000                0.000000
# 50%    1115.000000    11.000000             16.600000                0.000000
# 75%    1651.000000    17.500000             20.100000                0.000000
# max    2179.000000    23.000000             30.000000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count         1450.000000        1457.000000          1457.000000
# mean             2.479034          52.231297          1405.216884
# std              1.378265          20.370387           583.131708
# ...

# %%
test.describe()
# Out:
#                 id        hour  hour_bef_temperature  hour_bef_precipitation  \
# count   715.000000  715.000000            714.000000              714.000000
# mean   1056.854545   11.472727             23.263305                0.051821
# std     625.574471    6.928427              4.039645                0.221820
# min       0.000000    0.000000             14.600000                0.000000
# 25%     507.000000    5.500000             20.300000                0.000000
# 50%    1046.000000   11.000000             22.900000                0.000000
# 75%    1616.500000   17.000000             26.375000                0.000000
# max    2177.000000   23.000000             33.800000                1.000000
#
#        hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# count          714.000000         714.000000           714.000000
# mean             2.388515          56.668067          1359.494398
# std              1.171270          19.661880           614.171870
# ...

# %% [markdown]
# ### pd.DataFrame.groupby()
#  - 집단에 대한 통계량 확인
#
# <img src="https://s3.amazonaws.com/files.dezyre.com/images/Tutorials/Split+Apply+Combine+Strategy.png" width="700" height="500">

# %%
train.groupby('hour').mean() # 각 시간마다 데이터들의 평균값(0시간일때 0시간인 모든 데이터들의 평균값들 표시.)
# Out:
#                id  hour_bef_temperature  hour_bef_precipitation  \
# hour
# 0     1200.016667             14.788136                0.016949
# 1     1074.918033             14.155738                0.049180
# 2     1077.885246             13.747541                0.049180
# 3     1146.704918             13.357377                0.032787
# 4     1194.786885             13.001639                0.016393
# 5     1091.819672             12.673770                0.016393
# 6     1112.393443             12.377049                0.016393
# 7     1086.262295             12.191803                0.016393
# 8     1086.491803             12.600000                0.032787
# 9     1076.524590             14.318033                0.016393
# 10     965.704918             16.242623                0.016393
# 11    1208.803279             18.019672                0.000000
# 12    1149.639344             19.457377                0.016393
# 13     988.616667             20.648333                0.016667
# ...

# %%
train.groupby('hour').mean()['count']
# Out:
# hour
# 0      71.766667
# 1      47.606557
# 2      31.409836
# 3      21.377049
# 4      13.524590
# 5      13.114754
# 6      24.557377
# 7      62.360656
# 8     136.688525
# 9      93.540984
# 10     78.803279
# 11     88.327869
# 12    111.901639
# 13    120.050000
# 14    134.590164
# 15    152.967213
# 16    169.100000
# 17    187.133333
# 18    262.163934
# 19    201.606557
# 20    164.868852
# 21    168.816667
# 22    148.245902
# 23    103.852459
# Name: count, dtype: float64

# %%
train.groupby('hour').mean()['count'].plot()
# Out:
# <Axes: xlabel='hour'>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### plt.plot()의 스타일
#
# 색깔
#
# |문자열|약자|
# |----|-----|
# |blue|b|
# |green|g|
# |red|r|
# |cyan|c|
# |magenta|m|
# |yellow|y|
# |black|k|
# |white|w|
#
# 마커
#
# |마커|의미|
# |----|----|
# |.|점|
# |o|원|
# |v|역삼각형|
# |^|삼각형|
# |s|사각형|
# |*|별|
# |x|엑스|
# |d|다이아몬드|
#
# 선
#
# |문자열|의미|
# |-----|-----|
# | - | 실선|
# |-- | 끊어진 실선|
# | -.| 점+실선|
# |:|점선|

# %%
plt.plot(train.groupby('hour').mean()['count'], 'go-') # 색깔, 마커, 선 순(파랑 + 점 + 실선)
plt.grid() #격자

# %% [markdown]
# ### plt.title(label, fontsize)
# - 그래프 제목 생성
#
# ### plt.xlabel(label, fontsize)
# - x축 이름 설정
#
# ### plt.ylabel(label, fontsize)
# - y축 이름 설정

# %%
plt.plot(train.groupby('hour').mean()['count'], 'go-') # 색깔, 마커, 선 순(파랑 + 점 + 실선)
plt.grid() #격자

plt.title('count by hours', fontsize=15)
plt.xlabel('hour', fontsize=15)
plt.ylabel('count', fontsize=15)

plt.savefig('picture.png') # 그래프 저장법

# %% [markdown]
# ### plt.axvline(x, color)
# - 축을 가로지르는 세로 선 생성
#
# ### plt.axhline(y, color)
# - 축을 가로지르는 가로 선 생성
#
# ### plt.text(x, y, s, fontsize)
# - 원하는 위치에 텍스트 생성

# %%
plt.plot(train.groupby('hour').mean()['count'], 'go-') # 색깔, 마커, 선 순(파랑 + 점 + 실선)
plt.grid() #격자

plt.title('count by hours', fontsize=15)
plt.xlabel('hour', fontsize=15)
plt.ylabel('count', fontsize=15)

plt.axvline(8, color='r') #세로 선 그리기
plt.axvline(18, color='r') 

plt.text(8, 120, 'go work', fontsize=10) #글자 쓰기
plt.text(18, 120, 'go work', fontsize=10)

plt.savefig('picture.png') # 그래프 저장법

# %% [markdown]
# ### 상관계수

# %% [markdown]
# - 상관계수: 두 개의 변수가 같이 일어나는 강도를 나타내는 수치
# - -1에서 1사이의 값을 지닙니다.
# - -1이나 1인 수치는 현실 세계에서 관측되기 힘든 수치입니다.
# - 분야별로 기준을 정하는 것에 따라 달라지겠지만, 보통 0.4이상이면 두 개의 변수간에 상관성이 있다고 얘기합니다.

# %% [markdown]
# ![상관계수](https://t1.daumcdn.net/cfile/tistory/99DEE1425C6A9F2008)

# %% [markdown]
# - 상관관계는 인과관계와 다릅니다. 아래의 예시를 확인해 봅시다.

# %% [markdown]
# ![상관성 예시](https://miro.medium.com/max/684/1*JLYI5eCVEN7ZUWXBIrrapw.png)

# %% [markdown]
# - 선글라스 판매량이 증가함에 따라, 아이스크림 판매액도 같이 증가하는 것을 볼 수 있습니다.
# - 하지만 선글라스 판매량이 증가했기 **때문에** 아이스크림 판매액이 증가했다라고 해석하는 것은 타당하지 않습니다.
# - 선글라스 판매량이 증가했다는 것은 여름 때문이라고 볼 수 있으므로, 날씨가 더워짐에 따라 선글라스 판매량과 아이스크림 판매액이 같이 증가했다고 보는 것이 타당할 것입니다.

# %% [markdown]
# ### pd.DataFrame.corr()

# %% [markdown]
# - correlation coefficient 의 줄임말 입니다 (상관계수)

# %%
train.corr()
# Out:
#                               id      hour  hour_bef_temperature  \
# id                      1.000000 -0.010901             -0.000029
# hour                   -0.010901  1.000000              0.407306
# hour_bef_temperature   -0.000029  0.407306              1.000000
# hour_bef_precipitation -0.056267  0.021646             -0.097056
# hour_bef_windspeed     -0.003353  0.462797              0.375618
# hour_bef_humidity      -0.017948 -0.329612             -0.496088
# hour_bef_visibility     0.008950  0.176491              0.197417
# hour_bef_ozone          0.055234  0.390188              0.541228
# hour_bef_pm10          -0.025510 -0.035907             -0.003830
# hour_bef_pm2.5          0.003545 -0.061229             -0.078665
# count                  -0.002131  0.626047              0.619404
#
#                         hour_bef_precipitation  hour_bef_windspeed  \
# id                                   -0.056267           -0.003353
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,10)) 
sns.heatmap(train.corr(), annot=True) #숫자 같이 보는 옵션
# Out:
# <Axes: >

# %% [markdown]
# ## 3. 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %% [markdown]
# ### pd.Series.isna()
# - 결측치 여부를 확인해줍니다.
# - 결측치면 True, 아니면 False

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        2
# hour_bef_precipitation      2
# hour_bef_windspeed          9
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
train[train['hour_bef_temperature'].isna()] #결측치 위치 확인(0시와 18시의 데이터 2개가 결측됨.)
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0                   NaN                     NaN
# 1035  1553    18                   NaN                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
train.groupby('hour').mean()['hour_bef_temperature'].plot() #결측치를 무슨값으로 채울지 확인하기 위해 그래프로 확인(0시, 오후 6시)
plt.axhline(train.groupby('hour').mean()['hour_bef_temperature'].mean()) #전체의 평균값으로 채울경우 큰 차이 발생, 0시와 6시의 평균으로 채워야 함.

# %%
train.groupby('hour').mean()['hour_bef_temperature'] # 각 시간별 온도평균값
# Out:
# hour
# 0     14.788136
# 1     14.155738
# 2     13.747541
# 3     13.357377
# 4     13.001639
# 5     12.673770
# 6     12.377049
# 7     12.191803
# 8     12.600000
# 9     14.318033
# 10    16.242623
# 11    18.019672
# 12    19.457377
# 13    20.648333
# 14    21.234426
# 15    21.744262
# 16    22.015000
# 17    21.603333
# 18    20.926667
# 19    19.704918
# 20    18.191803
# 21    16.978333
# 22    16.063934
# 23    15.418033
# Name: hour_bef_temperature, dtype: float64

# %% [markdown]
# ### pd.DataFrame.fillna()
# - 결측치를 채우고자 하는 column과 결측치를 대신하여 넣고자 하는 값을 명시해주어야 합니다.

# %%
train['hour_bef_temperature'].fillna({934:14.788136, 1035:20.926667}, inplace=True) #각 시간의 온도평균값으로 대체

# %%
train.loc[[934, 1035], :]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 934   1420     0             14.788136                     NaN
# 1035  1553    18             20.926667                     NaN
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 934                  NaN                NaN                  NaN
# 1035                 NaN                NaN                  NaN
#
#       hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 934              NaN            NaN             NaN   39.0
# 1035             NaN            NaN             NaN    1.0

# %%
train[train['hour_bef_windspeed'].isna()]
# Out:
#         id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18      33    13             22.600000                     0.0
# 244    381     1             14.100000                     0.0
# 260    404     3             14.000000                     0.0
# 376    570     0             14.300000                     0.0
# 780   1196    20             16.500000                     0.0
# 934   1420     0             14.788136                     NaN
# 1035  1553    18             20.926667                     NaN
# 1138  1717    12             21.400000                     0.0
# 1229  1855     2             14.000000                     0.0
#
#       hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18                   NaN               41.0                987.0
# 244                  NaN               55.0               1992.0
# 260                  NaN               50.0               2000.0
# 376                  NaN               49.0               2000.0
# ...

# %%
plt.plot(train.groupby('hour').mean()['hour_bef_windspeed'])
plt.axhline(train.groupby('hour').mean()['hour_bef_windspeed'].mean(), color='r')

# %%
train[train['hour_bef_windspeed'].isna()].index #완전히 채워넣은 이후로는 출력되지 않는다(isna를 기준으로 했기 때문)
# Out:
# Int64Index([18, 244, 260, 376, 780, 934, 1035, 1138, 1229], dtype='int64')

# %%
train.groupby('hour').mean()['hour_bef_windspeed']
# Out:
# hour
# 0     1.965517
# 1     1.836667
# 2     1.633333
# 3     1.620000
# 4     1.409836
# 5     1.296721
# 6     1.331148
# 7     1.262295
# 8     1.632787
# 9     1.829508
# 10    2.122951
# 11    2.485246
# 12    2.766667
# 13    3.281356
# 14    3.522951
# 15    3.768852
# 16    3.820000
# 17    3.801667
# 18    3.838333
# 19    3.595082
# 20    3.278333
# 21    2.755000
# 22    2.498361
# 23    2.195082
# Name: hour_bef_windspeed, dtype: float64

# %%
train['hour_bef_windspeed'].fillna({18:3.281356, 244:1.836667, 260:1.620000, 376:1.965517, 780:3.278333, 934:1.965517, 1035:3.838333, 1138:2.766667, 1229:1.633333}, inplace=True)

# %%
train.loc[[18, 244], :]
# Out:
#       id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 18    33    13                  22.6                     0.0
# 244  381     1                  14.1                     0.0
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 18             3.281356               41.0                987.0
# 244            1.836667               55.0               1992.0
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5  count
# 18            0.046           64.0            39.0  208.0
# 244             NaN            NaN             NaN   38.0

# %%
train.isna().sum()
# Out:
# id                          0
# hour                        0
# hour_bef_temperature        0
# hour_bef_precipitation      2
# hour_bef_windspeed          0
# hour_bef_humidity           2
# hour_bef_visibility         2
# hour_bef_ozone             76
# hour_bef_pm10              90
# hour_bef_pm2.5            117
# count                       0
# dtype: int64

# %%
test.isna().sum()
# Out:
# id                         0
# hour                       0
# hour_bef_temperature       1
# hour_bef_precipitation     1
# hour_bef_windspeed         1
# hour_bef_humidity          1
# hour_bef_visibility        1
# hour_bef_ozone            35
# hour_bef_pm10             37
# hour_bef_pm2.5            36
# dtype: int64

# %%
test[test['hour_bef_temperature'].isna()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19                   NaN                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653                 NaN                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 653             NaN            NaN             NaN

# %%
test.groupby('hour').mean()['hour_bef_temperature']
# Out:
# hour
# 0     21.386667
# 1     20.986667
# 2     20.600000
# 3     20.203333
# 4     19.853333
# 5     19.634483
# 6     19.243333
# 7     19.190000
# 8     19.846667
# 9     21.266667
# 10    22.683333
# 11    24.110000
# 12    25.430000
# 13    26.630000
# 14    27.473333
# 15    28.040000
# 16    28.255172
# 17    27.848276
# 18    27.010345
# 19    26.110345
# 20    24.803333
# 21    23.696552
# 22    22.523333
# 23    21.926667
# Name: hour_bef_temperature, dtype: float64

# %%
test['hour_bef_temperature'].fillna({653:26.110345}, inplace=True)
test.loc[[653], :]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19             26.110345                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653                 NaN                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 653             NaN            NaN             NaN

# %%
test[test['hour_bef_windspeed'].isna()].index
# Out:
# Int64Index([653], dtype='int64')

# %%
test[test['hour_bef_windspeed'].isna()]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19             26.110345                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653                 NaN                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 653             NaN            NaN             NaN

# %%
test.groupby('hour').mean()['hour_bef_windspeed']
# Out:
# hour
# 0     1.986667
# 1     1.840000
# 2     1.823333
# 3     1.636667
# 4     1.543333
# 5     1.589655
# 6     1.396667
# 7     1.453333
# 8     1.446667
# 9     1.646667
# 10    1.920000
# 11    2.186667
# 12    2.636667
# 13    2.836667
# 14    2.903333
# 15    3.140000
# 16    3.406897
# 17    3.558621
# 18    3.503448
# 19    3.541379
# 20    3.406667
# 21    3.041379
# 22    2.686667
# 23    2.336667
# Name: hour_bef_windspeed, dtype: float64

# %%
test['hour_bef_windspeed'].fillna({653:3.541379}, inplace=True)
test.loc[[653], :]
# Out:
#        id  hour  hour_bef_temperature  hour_bef_precipitation  \
# 653  1943    19             26.110345                     NaN
#
#      hour_bef_windspeed  hour_bef_humidity  hour_bef_visibility  \
# 653            3.541379                NaN                  NaN
#
#      hour_bef_ozone  hour_bef_pm10  hour_bef_pm2.5
# 653             NaN            NaN             NaN

# %% [markdown]
# ## 4. 변수 선택 및 모델 구축
# ## Feature Engineering & Initial Modeling

# %%
# ?DecisionTreeRegressor #코드설명 보는법
#ctrl 스페이스바도 가능하다

# %%
features=['hour', 'hour_bef_temperature', 'hour_bef_windspeed']
X_train = train[features]
y_train = train['count']
X_test = test[features]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (1459, 3)
# (1459,)
# (715, 3)

# %%
from sklearn.tree import DecisionTreeRegressor  #랜덤 포레스트 설명용
from sklearn.ensemble import RandomForestRegressor  #랜덤 포레스트 불러오기

# %%
model100 = RandomForestRegressor(n_estimators=100, random_state=0) #각각의 나무들에게 예측값을 산출하라고 말을 함, 그 산풀값들중 가장 많이 나온 값 산출
model100_5 = RandomForestRegressor(n_estimators=100, random_state=0, max_depth=5)
model200 = RandomForestRegressor(n_estimators=200, random_state=0)
#n_estimators= 의사결정 나무의 개수
#n_jobs= 사용하고자 하는 cpu개수(-1 = 최대로 활용한다는 뜻)
#max_depth= 모델의 과대적합을 방지하기 위해 사용하는 옵션

#세가지 버전 모두 유효(분석하는 데이터마다 데이터에 적합한 옵션이 다름)
#가장 적합한 녀석으로 찾아봐야 함(tuning과정)

# %%
model100.fit(X_train, y_train)
model100_5.fit(X_train, y_train)
model200.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=0)

# %%
y_pred1 = model100.predict(X_test)
y_pred2 = model100_5.predict(X_test)
y_pred3 = model200.predict(X_test)
# TypeError: 'method' object is not subscriptable 에러가 뜨면 []를 ()로 바꿔봐라. groupby도 그래서 많이 틀렸다.

# %%
submission['count'] = y_pred1
submission.to_csv('model100.csv', index=False)

# %%
submission['count'] = y_pred2
submission.to_csv('model100_5.csv', index=False)

# %%
submission['count'] = y_pred3
submission.to_csv('model200.csv', index=False)
# 다 제출해 보면 200이 가장 잘 나옴.

# %% [markdown]
# ### sklearn.ensemble.RandomForestRegressor()
# - 랜덤 포레스트 모형

# %% [markdown]
# ## 5. 모델 학습 및 검증
# ## Model Tuning & Evaluation

# %% [markdown]
# ### model.fit()
# - 모델 학습

# %% [markdown]
# ### model.predict()
# - 모델 예측

# %% [markdown]
# ### pd.DataFrame.to_csv()
#  - csv파일 저장하는 함수

# %% [markdown]
# ## 6. 결과 및 결언
# ## Conclusion & Discussion
